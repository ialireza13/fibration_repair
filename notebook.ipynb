# %%
import numpy as np
import pandas as pd
from graph_repair import repair_network
# Out:
# Please install pyparsing, pydot & graphviz if you want to draw graphs or lattice diagrams

# %%
collapsed = 'collapsed'
prohibit_file = "sample_data/collapsed_prohibited_edges.txt"
df_weights = pd.read_csv('sample_data/collapsed_varshney_weights.txt', sep='\t', header=None)
n_cluster=6
df = pd.read_csv("sample_data/cons_6_colors_collapsed.txt", sep='\t', header=None)
a, b = 1, 1

EdgesRemoved, EdgesAdded, G_result = repair_network("sample_data/cons_6_colors_collapsed.txt", "sample_data/collapsed_varshney.graph.txt", f"sample_data/collapsed_consensous_6_colors_o_", a, b, prohibit_file_path=None)

# %%
EdgesRemoved, EdgesAdded
# Out:
# ([('AVD', 'DA04'),
#   ('AVD', 'DA01'),
#   ('AVD', 'DA09'),
#   ('AVD', 'VA03'),
#   ('AVD', 'VA11'),
#   ('AVE', 'VA03'),
#   ('AVE', 'VA04'),
#   ('DA04', 'DA03'),
#   ('VA12', 'DA08'),
#   ('VA12', 'DA09'),
#   ('VA02', 'VA03'),
#   ('VA03', 'VA04')],
#  [('AVE', 'VA07'),
#   ('AVE', 'DA07'),
#   ('AVE', 'VA06'),
#   ('AVE', 'DA06'),
#   ('AVA', 'VA07'),
#   ('AVA', 'VA01'),
#   ('VA12', 'VA10'),
#   ('VA05', 'AVE'),
#   ('AVD', 'VA07'),
#   ('VA02', 'DA06')])
